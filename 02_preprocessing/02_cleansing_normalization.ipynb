# %% [markdown]
# # 정제 (Cleansing) & 정규화 (Normalization)
#
# - 정제: 불필요한 특수 문자, 이모지, 구두점 등 텍스트 데이터에 포함된 노이즈 제거
# - 정규화: 같은 의미지만 표기가 다른 단어들을 일관된 표현으로 통일
#
# ### 정규화

# %%
# 규칙 기반 정규화 : 정해진 룰에 따라 치환 작업 (같은 의미를 가진 단어로 단어 통일)
text = 'NLP is fascinating. It has many applications in real-world scenarios'

transformed_text = text.replace('fascinating', 'good').replace('scenarios', 'stories')
transformed_text
# Out:
# 'NLP is good. It has many applications in real-world stories'

# %%
transformed_text = text.lower()
transformed_text
# Out:
# 'nlp is fascinating. it has many applications in real-world scenarios'

# %% [markdown]
# ### 정제
#
# 불필요한 단어 제거
#
# - 사용 빈도가 매우 적은 단어
# - 불용어 (자주 사용되지만 큰 의미를 갖지 않는 단어)
# - 특수문자

# %%
# 빈도수 낮은 단어 제거
from nltk.tokenize import word_tokenize
from collections import Counter

text = "The quick brown fox jumps over the lazy dog. The fox is quick and agile."

tokens = word_tokenize(text)
word_counts = Counter(tokens)  # 토큰별 등장 횟수

# 2회 이상 나온 토큰만 남김
filtered_tokens = [token for token in tokens if word_counts[token] >= 2]
filtered_tokens
# Out:
# ['The', 'quick', 'fox', '.', 'The', 'fox', 'quick', '.']

# %%
# 짧은 단어 제거 (길이 3이상만 남김)
filtered_tokens = [token for token in tokens if len(token) > 2]
filtered_tokens
# Out:
# ['The',
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog',
#  'The',
#  'fox',
#  'quick',
#  'and',
#  'agile']

# %%
from nltk.corpus import stopwords

en_stopwords = stopwords.words('english')
print(en_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
# 불용어 사전 활용한 토큰 필터링
tokens = word_tokenize(text)

filtered_tokens = [token for token in tokens if token.lower() not in en_stopwords]
filtered_tokens
# Out:
# ['quick',
#  'brown',
#  'fox',
#  'jumps',
#  'lazy',
#  'dog',
#  '.',
#  'fox',
#  'quick',
#  'agile',
#  '.']

# %%
from konlpy.tag import Okt

text = '이 눈깔! 이 눈깔! 왜 나를 똑바루 바라보지 못하고 천장만 바라 보느냐! 응?! \
설렁탕을 사왔는데… 왜 먹지를 못하니? 왜 먹지를 못하니! 괴상하게도 오늘은 운수가 좋더니만…'

okt = Okt()  # 객체 생성 (Okt 사용시 JVM 필요)

morphs = okt.morphs(text)  # 형태소 단위로 분리
morphs
# Out:
# ['이',
#  '눈',
#  '깔',
#  '!',
#  '이',
#  '눈',
#  '깔',
#  '!',
#  '왜',
#  '나를',
#  '똑바루',
#  '바라보지',
#  '못',
#  '하고',
#  '천장',
#  '만',
#  '바라',
#  '보느냐',
#  '!',
#  '응',
#  '?!',
#  '설렁탕',
#  '을',
#  '사왔는데',
#  '…',
#  '왜',
#  '먹지를',
#  '못',
#  '하니',
#  '?',
#  '왜',
#  '먹지를',
#  '못',
#  '하니',
#  '!',
#  '괴상하게도',
#  '오늘',
#  '은',
#  '운수',
#  '가',
#  '좋더니만',
#  '…']

# %%
# 파일 경로 받아서 불용어 로드하는 함수
def load_stopwords(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        stopwords = [line.strip() for line in f]  # 줄바꿈/공백 제거하여 리스트 생성 
    return stopwords

ko_stopwords = load_stopwords('ko_stopwords.txt')

cleaned_tokens = [token for token in tokens if token not in ko_stopwords]  # 불용어 제거 
cleaned_tokens
# Out:
# ['The',
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog',
#  '.',
#  'The',
#  'fox',
#  'is',
#  'quick',
#  'and',
#  'agile',
#  '.']
